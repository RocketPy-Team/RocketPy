# %%
from rocketpy import Function, LiquidMotor, MassFlowRateBasedTank, Fluid

# %%
LiquidN2O = Fluid(name='Liquid Nitrous Oxide', density=855, quality=1)
VapourN2O = Fluid(name='Vapour Nitrous Oxide', density=101, quality=0)

N2O_tank = MassFlowRateBasedTank(name='Oxidizer Tank',
                                diameter=0.2,
                                height=1.56,
                                endcap='flat',
                                initial_liquid_mass=42.45,
                                initial_gas_mass=0.95,
                                liquid_mass_flow_rate_in='../data/liquid_mass_flow_in.csv', #TO-DO: using this as a constant causes issues with Function class...
                                liquid_mass_flow_rate_out='../data/liquid_mass_flow_out.csv',
                                gas_mass_flow_rate_in='../data/gas_mass_flow_in.csv',
                                gas_mass_flow_rate_out='../data/gas_mass_flow_out.csv',
                                liquid=LiquidN2O,
                                gas=VapourN2O)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [4], line 4
#       1 LiquidN2O = Fluid(name='Liquid Nitrous Oxide', density=855, quality=1)
#       2 VapourN2O = Fluid(name='Vapour Nitrous Oxide', density=101, quality=0)
# ----> 4 N2O_tank = MassFlowRateBasedTank(name='Oxidizer Tank',
#       5                                 diameter=0.2,
#       6                                 height=1.56,
#       7                                 endcap='flat',
#       8                                 initial_liquid_mass=42.45,
#       9                                 initial_gas_mass=0.95,
#      10                                 liquid_mass_flow_rate_in='data/liquid_mass_flow_in.csv', #TO-DO: using this as a constant causes issues with Function class...
#      11                                 liquid_mass_flow_rate_out='data/liquid_mass_flow_out.csv',
#      12                                 gas_mass_flow_rate_in='data/gas_mass_flow_in.csv',
#      13                                 gas_mass_flow_rate_out='data/gas_mass_flow_out.csv',
#      14                                 liquid=LiquidN2O,
#      15                                 gas=VapourN2O)
#
# File ~/github/RocketPy/rocketpy/motors/LiquidMotor.py:195, in MassFlowRateBasedTank.__init__(self, name, diameter, height, gas, liquid, endcap, initial_liquid_mass, initial_gas_mass, liquid_mass_flow_rate_in, gas_mass_flow_rate_in, liquid_mass_flow_rate_out, gas_mass_flow_rate_out)
#     192 self.initial_liquid_mass = initial_liquid_mass
#     193 self.initial_gas_mass = initial_gas_mass
# --> 195 self.gas_mass_flow_rate_in = Function(
#     196     gas_mass_flow_rate_in,
#     197     "Time (s)",
#     198     "Inlet Gas Propellant Mass Flow Rate (kg/s)",
#     199     "linear",
#     200     "constant",
#     201 )
#     203 self.gas_mass_flow_rate_out = Function(
#     204     gas_mass_flow_rate_out,
#     205     "Time (s)",
#    (...)
#     208     "constant",
#     209 )
#     211 self.liquid_mass_flow_rate_in = Function(
#     212     liquid_mass_flow_rate_in,
#     213     "Time (s)",
#    (...)
#     216     "constant",
#     217 )
#
# File ~/github/RocketPy/rocketpy/Function.py:75, in Function.__init__(self, source, inputs, outputs, interpolation, extrapolation)
#      73 self.last_interval = 0
#      74 # Set source
# ---> 75 self.setSource(source)
#      76 # Return
#      77 return None
#
# File ~/github/RocketPy/rocketpy/Function.py:134, in Function.setSource(self, source)
#     131 # Import CSV if source is a string and convert values to ndarray
#     132 if isinstance(source, str):
#     133     # Read file and check for headers
# --> 134     f = open(source, "r")
#     135     firstLine = f.readline()
#     136     # If headers are found...
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/gas_mass_flow_in.csv'

# %%
N2O_tank.netMassFlowRate()

N2O_tank.liquid_mass_flow_rate_in.plot()
N2O_tank.liquid_mass_flow_rate_out.plot()
N2O_tank.liquid_net_mass_flow_rate.plot()
N2O_tank.net_mass_flow_rate()

# %%
N2O_tank.mass()

# %%
N2O_tank.liquidVolume()

# %%
center_of_mass = Function(lambda t: N2O_tank.centerOfMass(t))
center_of_mass.plot(0,25)

# %%
inertiaI = Function(lambda t: N2O_tank.inertiaTensor(t)[0])
inertiaZ = Function(lambda t: N2O_tank.inertiaTensor(t)[1])

inertiaI.setOutputs("Moment of Inertia I of Liquid (kg*m^2)")
inertiaI.plot(0,25)
